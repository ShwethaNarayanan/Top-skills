# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Exploratory Data Analysis Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this module you get to work with the cleaned dataset from the previous module.
#
# In this assignment you will perform the task of exploratory data analysis.
# You will find out the distribution of data, presence of outliers and also determine the correlation between different columns in the dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# *   Identify the distribution of data in the dataset.
#
# *   Identify outliers in the dataset.
#
# *   Remove outliers from the dataset.
#
# *   Identify correlation between features in the dataset.

# %% [markdown]
# ***

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import the pandas module.

# %%
import pandas as pd
import numpy as np
from numpy import percentile
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# %% [markdown]
# ## Distribution

# %% [markdown]
# ### Determine how the data is distributed

# %% [markdown]
# The column `ConvertedComp` contains Salary converted to annual USD salaries using the exchange rate on 2019-02-01.
#
# This assumes 12 working months and 50 working weeks.

# %% [markdown]
# Plot the distribution curve for the column `ConvertedComp`.

# %%
sns.distplot(df['ConvertedComp'], hist = False)
# Out:
# <AxesSubplot:xlabel='ConvertedComp'>

# %% [markdown]
# Plot the histogram for the column `ConvertedComp`.

# %%
count, bin_edges = np.histogram(df['ConvertedComp'].dropna())

df['ConvertedComp'].plot(kind = 'hist', xticks=bin_edges)

plt.title('Histogram of Salary')
plt.xlabel('Salary in USD')
plt.ylabel('Count')

plt.show()

# %% [markdown]
# What is the median of the column `ConvertedComp`?

# %%
df['ConvertedComp'].median()
# Out:
# 57745.0

# %% [markdown]
# How many responders identified themselves only as a **Man**?

# %%
df[df['Gender']=='Man']['Gender'].value_counts()
# Out:
# Man    10480
# Name: Gender, dtype: int64

# %% [markdown]
# Find out the  median ConvertedComp of responders identified themselves only as a **Woman**?

# %%
df[df['Gender']=='Woman']['ConvertedComp'].median()
# Out:
# 57708.0

# %% [markdown]
# Give the five number summary for the column `Age`?

# %% [markdown]
# **Double click here for hint**.
#
# <!--
# min,q1,median,q3,max of a column are its five number summary.
# -->

# %%
df['Age'].describe()
# Out:
# count    11111.000000
# mean        30.778895
# std          7.393686
# min         16.000000
# 25%         25.000000
# 50%         29.000000
# 75%         35.000000
# max         99.000000
# Name: Age, dtype: float64

# %% [markdown]
# Plot a histogram of the column `Age`.

# %%
df['Age'].plot(kind='hist')

plt.title('Histogram of Age') 
plt.xlabel('Age')
plt.ylabel('Count')

plt.show()

# %% [markdown]
# ## Outliers

# %% [markdown]
# ### Finding outliers

# %% [markdown]
# Find out if outliers exist in the column `ConvertedComp` using a box plot?

# %%
df['ConvertedComp'].plot(kind='box')

plt.title('Box plot of Salalry in USD')

plt.show()

# %% [markdown]
# Find out the Inter Quartile Range for the column `ConvertedComp`.

# %%
print(df['ConvertedComp'].describe())
# IQR = Q3 - Q1    (Q3: 75% and Q1: 25%)
Q1 = df['ConvertedComp'].describe()[4]
Q3 = df['ConvertedComp'].describe()[6]
IQR = Q3 - Q1
IQR
# Out:
# count    1.058200e+04
# mean     1.315967e+05
# std      2.947865e+05
# min      0.000000e+00
# 25%      2.686800e+04
# 50%      5.774500e+04
# 75%      1.000000e+05
# max      2.000000e+06
# Name: ConvertedComp, dtype: float64
# 73132.0

# %% [markdown]
# Find out the upper and lower bounds.

# %%
const = 1.5 * IQR
lower = Q1 - const 
upper = Q3 + const 
print("Lower bound: {},  Upper bound: {}".format(lower, upper))
# Out:
# Lower bound: -82830.0,  Upper bound: 209698.0

# %% [markdown]
# Identify how many outliers are there in the `ConvertedComp` column.

# %%
# Outliers : Values over Q3 + (1.5 * IQR) or values less than Q1 - (1.5 * IQR)
#df=df.reset_index()
print(df[(df['ConvertedComp']> upper) | (df['ConvertedComp']< lower)].shape)
df[(df['ConvertedComp']> upper) | (df['ConvertedComp']< lower)].head()
# Out:
# (879, 87)
#     level_0  index  Respondent  \
# 3         3      3          16
# 13       13     13          32
# 45       45     45         100
# 46       46     46         102
# 60       60     60         128
#
#                                            MainBranch Hobbyist  \
# 3                      I am a developer by profession      Yes
# 13                     I am a developer by profession       No
# 45                     I am a developer by profession      Yes
# 46                     I am a developer by profession       No
# 60  I am not primarily a developer, but I write co...      Yes
#
#                    OpenSourcer  \
# 3                        Never
# 13                       Never
# 45  Once a month or more often
# 46                       Never
# 60  Once a month or more often
#
#                                            OpenSource          Employment  \
# 3   The quality of OSS and closed source software ...  Employed full-time
# 13  The quality of OSS and closed source software ...  Employed full-time
# 45  The quality of OSS and closed source software ...  Employed full-time
# 46  The quality of OSS and closed source software ...  Employed full-time
# 60  OSS is, on average, of HIGHER quality than pro...  Employed full-time
#
#            Country Student  ...                             WelcomeChange  \
# 3   United Kingdom      No  ...   Just as welcome now as I felt last year
# 13   United States      No  ...  Somewhat more welcome now than last year
# 45          Canada      No  ...   Just as welcome now as I felt last year
# 46   United States      No  ...   Just as welcome now as I felt last year
# 60  United Kingdom      No  ...   Just as welcome now as I felt last year
#
#                                          SONewContent   Age Gender Trans  \
# 3   Tech articles written by other developers;Indu...  26.0    Man    No
# 13  Tech articles written by other developers;Indu...  21.0    Man    No
# 45                                                NaN  39.0  Woman    No
# 46  Tech articles written by other developers;Indu...  37.0    Man    No
# 60  Tech articles written by other developers;Indu...  30.0    Man    No
#
#                   Sexuality                     Ethnicity Dependents  \
# 3   Straight / Heterosexual  White or of European descent         No
# 13  Straight / Heterosexual  White or of European descent         No
# 45                 Bisexual  White or of European descent         No
# 46  Straight / Heterosexual  White or of European descent        Yes
# 60                 Bisexual  White or of European descent        Yes
#
#              SurveyLength                  SurveyEase
# 3   Appropriate in length  Neither easy nor difficult
# 13  Appropriate in length  Neither easy nor difficult
# 45  Appropriate in length                        Easy
# 46               Too long                        Easy
# 60               Too long                        Easy
#
# [5 rows x 87 columns]

# %% [markdown]
# Create a new dataframe by removing the outliers from the `ConvertedComp` column.

# %%
df_new = df[(df['ConvertedComp']>=lower) & (df['ConvertedComp']<= upper)]
print(df['ConvertedComp'].median())
print(df_new.shape)
df_new.head()
print(df_new['ConvertedComp'].median())
print(df_new['ConvertedComp'].mean())
# Out:
# 57745.0
# (9703, 87)
# 52704.0
# 59883.20838915799

# %% [markdown]
# ## Correlation

# %% [markdown]
# ### Finding correlation

# %% [markdown]
# Find the correlation between `Age` and all other numerical columns.

# %%
df.corr()['Age']
# Out:
# Respondent       0.004041
# CompTotal        0.006970
# ConvertedComp    0.105386
# WorkWeekHrs      0.036518
# CodeRevHrs      -0.020469
# Age              1.000000
# Name: Age, dtype: float64

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
